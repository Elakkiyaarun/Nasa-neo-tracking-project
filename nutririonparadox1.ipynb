# %%
import requests

url="https://ghoapi.azureedge.net/api/NCD_BMI_30C"
result = requests.get(url)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
import pandas as pd
df1=pd.DataFrame(data['value'])
df1.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7359329   NCD_BMI_30C        COUNTRY        MUS                AFR
# 1      256   NCD_BMI_30C        COUNTRY        KHM                WPR
# 2      349   NCD_BMI_30C        COUNTRY        IRN                EMR
# 3      808   NCD_BMI_30C        COUNTRY        TJK                EUR
# 4     1051   NCD_BMI_30C        COUNTRY        WSM                WPR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR                 Africa      SEX     1992   SEX_MLE  ...
# 1        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 2        YEAR  Eastern Mediterranean      SEX     2020   SEX_MLE  ...
# 3        YEAR                 Europe      SEX     1995  SEX_FMLE  ...
# 4        YEAR        Western Pacific      SEX     2003  SEX_BTSX  ...
#
#   DataSourceDim             Value NumericValue       Low      High Comments  \
# ...

# %%
df1['Age_group']='Adult'
df1
# Out:
#             Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0      7359329   NCD_BMI_30C        COUNTRY        MUS                AFR
# 1          256   NCD_BMI_30C        COUNTRY        KHM                WPR
# 2          349   NCD_BMI_30C        COUNTRY        IRN                EMR
# 3          808   NCD_BMI_30C        COUNTRY        TJK                EUR
# 4         1051   NCD_BMI_30C        COUNTRY        WSM                WPR
# ...        ...           ...            ...        ...                ...
# 20785  9762804   NCD_BMI_30C        COUNTRY        LTU                EUR
# 20786  9763485   NCD_BMI_30C        COUNTRY        ARM                EUR
# 20787  9764823   NCD_BMI_30C        COUNTRY        ERI                AFR
# 20788  9764930   NCD_BMI_30C        COUNTRY        VCT                AMR
# 20789  9765018   NCD_BMI_30C        COUNTRY        TUN                EMR
#
#       TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# ...

# %%
url="https://ghoapi.azureedge.net/api/NCD_BMI_PLUS2C"
result = requests.get(url)
data = result.json()

# %%
df2=pd.DataFrame(data['value'])
df2.head()
# Out:
#         Id   IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7358518  NCD_BMI_PLUS2C        COUNTRY        BRN                WPR
# 1  7358754  NCD_BMI_PLUS2C        COUNTRY        FJI                WPR
# 2  7358798  NCD_BMI_PLUS2C        COUNTRY        CMR                AFR
# 3  7358812  NCD_BMI_PLUS2C        COUNTRY        BGD               SEAR
# 4  7358813  NCD_BMI_PLUS2C        COUNTRY        PRI                AMR
#
#   TimeDimType   ParentLocation Dim1Type      Dim1  TimeDim  ... DataSourceDim  \
# 0        YEAR  Western Pacific      SEX   SEX_MLE     2007  ...          None
# 1        YEAR  Western Pacific      SEX   SEX_MLE     1997  ...          None
# 2        YEAR           Africa      SEX  SEX_BTSX     1999  ...          None
# 3        YEAR  South-East Asia      SEX  SEX_BTSX     2006  ...          None
# 4        YEAR         Americas      SEX  SEX_BTSX     2021  ...          None
#
# ...

# %%
df2['Age_group']='Child'
df2.head()
# Out:
#         Id   IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7358518  NCD_BMI_PLUS2C        COUNTRY        BRN                WPR
# 1  7358754  NCD_BMI_PLUS2C        COUNTRY        FJI                WPR
# 2  7358798  NCD_BMI_PLUS2C        COUNTRY        CMR                AFR
# 3  7358812  NCD_BMI_PLUS2C        COUNTRY        BGD               SEAR
# 4  7358813  NCD_BMI_PLUS2C        COUNTRY        PRI                AMR
#
#   TimeDimType   ParentLocation Dim1Type      Dim1  TimeDim  ...  \
# 0        YEAR  Western Pacific      SEX   SEX_MLE     2007  ...
# 1        YEAR  Western Pacific      SEX   SEX_MLE     1997  ...
# 2        YEAR           Africa      SEX  SEX_BTSX     1999  ...
# 3        YEAR  South-East Asia      SEX  SEX_BTSX     2006  ...
# 4        YEAR         Americas      SEX  SEX_BTSX     2021  ...
#
#               Value NumericValue       Low      High Comments  \
# 0  14.7 [10.0-20.1]     14.72553   9.98891  20.08075     None
# ...

# %%
###concatenated two df to create df_obesity
df_obesity=pd.concat([df1,df2])
df_obesity.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7359329   NCD_BMI_30C        COUNTRY        MUS                AFR
# 1      256   NCD_BMI_30C        COUNTRY        KHM                WPR
# 2      349   NCD_BMI_30C        COUNTRY        IRN                EMR
# 3      808   NCD_BMI_30C        COUNTRY        TJK                EUR
# 4     1051   NCD_BMI_30C        COUNTRY        WSM                WPR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR                 Africa      SEX     1992   SEX_MLE  ...
# 1        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 2        YEAR  Eastern Mediterranean      SEX     2020   SEX_MLE  ...
# 3        YEAR                 Europe      SEX     1995  SEX_FMLE  ...
# 4        YEAR        Western Pacific      SEX     2003  SEX_BTSX  ...
#
#               Value NumericValue       Low      High Comments  \
# ...

# %%
####Removed the columns which is not specifiedin obese
df_obestity = df_obesity.drop(['Id','IndicatorCode','SpatialDimType','TimeDimType','ParentLocationCode','Dim1Type','Value','Comments','Dim2Type','Dim2','Dim3Type','Dim3','DataSourceDimType','DataSourceDim','TimeDimensionValue','Date','TimeDimensionBegin','TimeDimensionEnd'],axis=1,inplace=True)
df_obesity.head()
# Out:
#   SpatialDim         ParentLocation  TimeDim      Dim1  NumericValue  \
# 0        MUS                 Africa     1992   SEX_MLE       4.60805
# 1        KHM        Western Pacific     2001  SEX_BTSX       0.98170
# 2        IRN  Eastern Mediterranean     2020   SEX_MLE      17.48764
# 3        TJK                 Europe     1995  SEX_FMLE       7.90484
# 4        WSM        Western Pacific     2003  SEX_BTSX      46.62329
#
#         Low      High Age_group
# 0   3.76625   5.57573     Adult
# 1   0.75674   1.27487     Adult
# 2  15.79378  19.24573     Adult
# 3   5.78327  10.38715     Adult
# 4  44.61686  48.69747     Adult

# %%
url_3="https://ghoapi.azureedge.net/api/NCD_BMI_18C"
result = requests.get(url_3)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
df_1=pd.DataFrame(data['value'])
df_1.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7358527   NCD_BMI_18C        COUNTRY        ARE                EMR
# 1  7358627   NCD_BMI_18C        COUNTRY        PLW                WPR
# 2       53   NCD_BMI_18C        COUNTRY        GAB                AFR
# 3      404   NCD_BMI_18C        COUNTRY        TUV                WPR
# 4     1633   NCD_BMI_18C        COUNTRY        GHA                AFR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR  Eastern Mediterranean      SEX     2013   SEX_MLE  ...
# 1        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 2        YEAR                 Africa      SEX     2021  SEX_FMLE  ...
# 3        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 4        YEAR                 Africa      SEX     2002   SEX_MLE  ...
#
#   DataSourceDim             Value NumericValue       Low      High Comments  \
# ...

# %%
df_1['Age_group']='Adult'
df_1.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7358527   NCD_BMI_18C        COUNTRY        ARE                EMR
# 1  7358627   NCD_BMI_18C        COUNTRY        PLW                WPR
# 2       53   NCD_BMI_18C        COUNTRY        GAB                AFR
# 3      404   NCD_BMI_18C        COUNTRY        TUV                WPR
# 4     1633   NCD_BMI_18C        COUNTRY        GHA                AFR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR  Eastern Mediterranean      SEX     2013   SEX_MLE  ...
# 1        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 2        YEAR                 Africa      SEX     2021  SEX_FMLE  ...
# 3        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 4        YEAR                 Africa      SEX     2002   SEX_MLE  ...
#
#               Value NumericValue       Low      High Comments  \
# ...

# %%
url_4="https://ghoapi.azureedge.net/api/NCD_BMI_MINUS2C"
result = requests.get(url_4)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
df_2=pd.DataFrame(data['value'])
df_2.head()
# Out:
#         Id    IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  7358586  NCD_BMI_MINUS2C        COUNTRY        SUR        YEAR
# 1  7358703  NCD_BMI_MINUS2C        COUNTRY        LAO        YEAR
# 2  7359248  NCD_BMI_MINUS2C        COUNTRY        TGO        YEAR
# 3  7359337  NCD_BMI_MINUS2C        COUNTRY        GTM        YEAR
# 4       24  NCD_BMI_MINUS2C        COUNTRY        AUT        YEAR
#
#   ParentLocationCode   ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                AMR         Americas      SEX     2005   SEX_MLE  ...
# 1                WPR  Western Pacific      SEX     2011   SEX_MLE  ...
# 2                AFR           Africa      SEX     1995  SEX_BTSX  ...
# 3                AMR         Americas      SEX     2014  SEX_BTSX  ...
# 4                EUR           Europe      SEX     2009  SEX_FMLE  ...
#
#   DataSourceDim            Value NumericValue      Low      High Comments  \
# ...

# %%
df_2['Age_group']='Child'
df_2.head()
# Out:
#         Id    IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  7358586  NCD_BMI_MINUS2C        COUNTRY        SUR        YEAR
# 1  7358703  NCD_BMI_MINUS2C        COUNTRY        LAO        YEAR
# 2  7359248  NCD_BMI_MINUS2C        COUNTRY        TGO        YEAR
# 3  7359337  NCD_BMI_MINUS2C        COUNTRY        GTM        YEAR
# 4       24  NCD_BMI_MINUS2C        COUNTRY        AUT        YEAR
#
#   ParentLocationCode   ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                AMR         Americas      SEX     2005   SEX_MLE  ...
# 1                WPR  Western Pacific      SEX     2011   SEX_MLE  ...
# 2                AFR           Africa      SEX     1995  SEX_BTSX  ...
# 3                AMR         Americas      SEX     2014  SEX_BTSX  ...
# 4                EUR           Europe      SEX     2009  SEX_FMLE  ...
#
#              Value NumericValue      Low      High Comments  \
# 0   4.3 [1.0-10.4]      4.25176  1.01784  10.39034     None
# ...

# %%
df_malnutrition=pd.concat([df_1,df_2])
df_malnutrition.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7358527   NCD_BMI_18C        COUNTRY        ARE                EMR
# 1  7358627   NCD_BMI_18C        COUNTRY        PLW                WPR
# 2       53   NCD_BMI_18C        COUNTRY        GAB                AFR
# 3      404   NCD_BMI_18C        COUNTRY        TUV                WPR
# 4     1633   NCD_BMI_18C        COUNTRY        GHA                AFR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR  Eastern Mediterranean      SEX     2013   SEX_MLE  ...
# 1        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 2        YEAR                 Africa      SEX     2021  SEX_FMLE  ...
# 3        YEAR        Western Pacific      SEX     2001  SEX_BTSX  ...
# 4        YEAR                 Africa      SEX     2002   SEX_MLE  ...
#
#               Value NumericValue       Low      High Comments  \
# ...

# %%
df_malnutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83160 entries, 0 to 62369
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  83160 non-null  int64
#  1   IndicatorCode       83160 non-null  object
#  2   SpatialDimType      83160 non-null  object
#  3   SpatialDim          83160 non-null  object
#  4   ParentLocationCode  78804 non-null  object
#  5   TimeDimType         83160 non-null  object
#  6   ParentLocation      78804 non-null  object
#  7   Dim1Type            83160 non-null  object
#  8   TimeDim             83160 non-null  int64
#  9   Dim1                83160 non-null  object
#  10  Dim2Type            83160 non-null  object
#  11  Dim2                83160 non-null  object
#  12  Dim3Type            0 non-null      object
#  13  Dim3                0 non-null      object
#  14  DataSourceDimType   0 non-null      object
# ...

# %%
####Removed the columns which is not specified in malnut
df_malnutrution=df_malnutrition.drop(['Id','IndicatorCode','SpatialDimType','ParentLocationCode','TimeDimType','Dim1Type','Dim2Type','Dim2','Dim3Type','Dim3','DataSourceDimType','DataSourceDim','Value','Comments','Date','TimeDimensionValue','TimeDimensionBegin','TimeDimensionEnd'],axis=1,inplace=True)

# %%
df_malnutrition.head()
# Out:
#   SpatialDim         ParentLocation  TimeDim      Dim1  NumericValue  \
# 0        ARE  Eastern Mediterranean     2013   SEX_MLE       3.00419
# 1        PLW        Western Pacific     2001  SEX_BTSX       1.40987
# 2        GAB                 Africa     2021  SEX_FMLE       5.79511
# 3        TUV        Western Pacific     2001  SEX_BTSX       0.93657
# 4        GHA                 Africa     2002   SEX_MLE      13.20428
#
#         Low      High Age_group
# 0   1.94130   4.32408     Adult
# 1   0.76648   2.30156     Adult
# 2   3.97204   8.07702     Adult
# 3   0.36515   1.85929     Adult
# 4  10.04854  16.71203     Adult

# %%
###renaming columns in obese
df_obesity=df_obesity.rename(columns={'TimeDim':'year','Dim1':'gender','NumericValue': 'mean_estimate','Low':'LowerBound','High':'HigherBound','ParentLocation':'Region','SpatialDim':'Country'})
df_obesity.head()
# Out:
#   Country                 Region  year    gender  mean_estimate  LowerBound  \
# 0     MUS                 Africa  1992   SEX_MLE        4.60805     3.76625
# 1     KHM        Western Pacific  2001  SEX_BTSX        0.98170     0.75674
# 2     IRN  Eastern Mediterranean  2020   SEX_MLE       17.48764    15.79378
# 3     TJK                 Europe  1995  SEX_FMLE        7.90484     5.78327
# 4     WSM        Western Pacific  2003  SEX_BTSX       46.62329    44.61686
#
#    HigherBound Age_group
# 0      5.57573     Adult
# 1      1.27487     Adult
# 2     19.24573     Adult
# 3     10.38715     Adult
# 4     48.69747     Adult

# %%
###renaming columns in malnut
df_malnutrition=df_malnutrition.rename(columns={'TimeDim':'year','Dim1':'gender','NumericValue': 'mean_estimate','Low':'LowerBound','High':'HigherBound','ParentLocation':'Region','SpatialDim':'Country'})
df_malnutrition.head()
# Out:
#   Country                 Region  year    gender  mean_estimate  LowerBound  \
# 0     ARE  Eastern Mediterranean  2013   SEX_MLE        3.00419     1.94130
# 1     PLW        Western Pacific  2001  SEX_BTSX        1.40987     0.76648
# 2     GAB                 Africa  2021  SEX_FMLE        5.79511     3.97204
# 3     TUV        Western Pacific  2001  SEX_BTSX        0.93657     0.36515
# 4     GHA                 Africa  2002   SEX_MLE       13.20428    10.04854
#
#    HigherBound Age_group
# 0      4.32408     Adult
# 1      2.30156     Adult
# 2      8.07702     Adult
# 3      1.85929     Adult
# 4     16.71203     Adult

# %%
df_malnutrition.tail()
# Out:
#       Country           Region  year    gender  mean_estimate  LowerBound  \
# 62365     PNG  Western Pacific  2009  SEX_FMLE        1.11686     0.10550
# 62366     WSM  Western Pacific  2020  SEX_FMLE        0.73407     0.06415
# 62367     IDN  South-East Asia  1999   SEX_MLE       13.28270    11.34984
# 62368     MWI           Africa  2003  SEX_FMLE        3.76525     2.65127
# 62369     ISL           Europe  2018   SEX_MLE        2.54279     0.46517
#
#        HigherBound Age_group
# 62365      3.96189     Child
# 62366      2.81018     Child
# 62367     15.32561     Child
# 62368      5.06782     Child
# 62369      7.30748     Child

# %%
###ci width included in obese
df_obesity['CI_width']=df_obesity['HigherBound']-df_obesity['LowerBound']
df_obesity.head()
# Out:
#   Country                 Region  year    gender  mean_estimate  LowerBound  \
# 0     MUS                 Africa  1992   SEX_MLE        4.60805     3.76625
# 1     KHM        Western Pacific  2001  SEX_BTSX        0.98170     0.75674
# 2     IRN  Eastern Mediterranean  2020   SEX_MLE       17.48764    15.79378
# 3     TJK                 Europe  1995  SEX_FMLE        7.90484     5.78327
# 4     WSM        Western Pacific  2003  SEX_BTSX       46.62329    44.61686
#
#    HigherBound Age_group  CI_width
# 0      5.57573     Adult   1.80948
# 1      1.27487     Adult   0.51813
# 2     19.24573     Adult   3.45195
# 3     10.38715     Adult   4.60388
# 4     48.69747     Adult   4.08061

# %%
###ci width included in malnutrition
df_malnutrition['CI_width']=df_malnutrition['HigherBound']-df_malnutrition['LowerBound']
df_malnutrition.head()
# Out:
#   Country                 Region  year    gender  mean_estimate  LowerBound  \
# 0     ARE  Eastern Mediterranean  2013   SEX_MLE        3.00419     1.94130
# 1     PLW        Western Pacific  2001  SEX_BTSX        1.40987     0.76648
# 2     GAB                 Africa  2021  SEX_FMLE        5.79511     3.97204
# 3     TUV        Western Pacific  2001  SEX_BTSX        0.93657     0.36515
# 4     GHA                 Africa  2002   SEX_MLE       13.20428    10.04854
#
#    HigherBound Age_group  CI_width
# 0      4.32408     Adult   2.38278
# 1      2.30156     Adult   1.53508
# 2      8.07702     Adult   4.10498
# 3      1.85929     Adult   1.49414
# 4     16.71203     Adult   6.66349

# %%
###filtered year from 2012 to 2022 in obese
df_obesity= df_obesity[(df_obesity['year'] >= 2012) & (df_obesity['year'] <= 2022)]
df_obesity.head()
# Out:
#    Country                 Region  year    gender  mean_estimate  LowerBound  \
# 2      IRN  Eastern Mediterranean  2020   SEX_MLE       17.48764    15.79378
# 9      IRQ  Eastern Mediterranean  2020   SEX_MLE       28.33553    23.08959
# 15     GRL                 Europe  2014  SEX_FMLE       27.94870    24.92477
# 17     ARM                 Europe  2019  SEX_FMLE       31.89322    28.16068
# 18     MLT                 Europe  2018  SEX_BTSX       33.69421    29.90581
#
#     HigherBound Age_group  CI_width
# 2      19.24573     Adult   3.45195
# 9      33.81534     Adult  10.72575
# 15     31.21326     Adult   6.28849
# 17     35.57493     Adult   7.41425
# 18     37.47086     Adult   7.56505

# %%
###filtered year from 2012 to 2022 in malnut
df_malnutrition= df_malnutrition[(df_malnutrition['year'] >= 2012) & (df_malnutrition['year'] <= 2022)]
df_malnutrition.head()
# Out:
#   Country                 Region  year    gender  mean_estimate  LowerBound  \
# 0     ARE  Eastern Mediterranean  2013   SEX_MLE        3.00419     1.94130
# 2     GAB                 Africa  2021  SEX_FMLE        5.79511     3.97204
# 6     MNG        Western Pacific  2017  SEX_BTSX        3.09065     2.42823
# 7     SLE                 Africa  2016  SEX_FMLE        8.37172     6.65567
# 9    SEAR                   None  2021  SEX_BTSX       13.33635    12.24232
#
#    HigherBound Age_group  CI_width
# 0      4.32408     Adult   2.38278
# 2      8.07702     Adult   4.10498
# 6      3.84215     Adult   1.41392
# 7     10.25312     Adult   3.59745
# 9     14.44287     Adult   2.20055

# %%
###In the Gender column, standardize values to 'Male', 'Female', and 'Both' in df_obese
df_obesity['gender'] = df_obesity['gender'].replace({'SEX_BTSX': 'Both', 'SEX_MLE': 'Male','SEX_FMLE':'Female'})
df_obesity.head()
# Out:
#    Country                 Region  year  gender  mean_estimate  LowerBound  \
# 2      IRN  Eastern Mediterranean  2020    Male       17.48764    15.79378
# 9      IRQ  Eastern Mediterranean  2020    Male       28.33553    23.08959
# 15     GRL                 Europe  2014  Female       27.94870    24.92477
# 17     ARM                 Europe  2019  Female       31.89322    28.16068
# 18     MLT                 Europe  2018    Both       33.69421    29.90581
#
#     HigherBound Age_group  CI_width
# 2      19.24573     Adult   3.45195
# 9      33.81534     Adult  10.72575
# 15     31.21326     Adult   6.28849
# 17     35.57493     Adult   7.41425
# 18     37.47086     Adult   7.56505

# %%
###In the Gender column, standardize values to 'Male', 'Female', and 'Both' in df_malnut
df_malnutrition['gender'] = df_malnutrition['gender'].replace({'SEX_BTSX': 'Both', 'SEX_MLE': 'Male','SEX_FMLE':'Female'})
df_malnutrition.head()
# Out:
#   Country                 Region  year  gender  mean_estimate  LowerBound  \
# 0     ARE  Eastern Mediterranean  2013    Male        3.00419     1.94130
# 2     GAB                 Africa  2021  Female        5.79511     3.97204
# 6     MNG        Western Pacific  2017    Both        3.09065     2.42823
# 7     SLE                 Africa  2016  Female        8.37172     6.65567
# 9    SEAR                   None  2021    Both       13.33635    12.24232
#
#    HigherBound Age_group  CI_width
# 0      4.32408     Adult   2.38278
# 2      8.07702     Adult   4.10498
# 6      3.84215     Adult   1.41392
# 7     10.25312     Adult   3.59745
# 9     14.44287     Adult   2.20055

# %%
df_obesity['obesity_level']= 'nan'

# %%
###adding obesity level with conditions in df_obese
import numpy as np

conditions = [
    df_obesity['mean_estimate'] >= 30,
    (df_obesity['mean_estimate'] >= 25) & (df_obesity['mean_estimate'] < 30),
    df_obesity['mean_estimate'] < 25
]

choices = ['High', 'Moderate', 'Low']

df_obesity['obesity_level'] = np.select(conditions, choices)
df_obesity.head()
# Out:
#    Country                 Region  year  gender  mean_estimate  LowerBound  \
# 2      IRN  Eastern Mediterranean  2020    Male       17.48764    15.79378
# 9      IRQ  Eastern Mediterranean  2020    Male       28.33553    23.08959
# 15     GRL                 Europe  2014  Female       27.94870    24.92477
# 17     ARM                 Europe  2019  Female       31.89322    28.16068
# 18     MLT                 Europe  2018    Both       33.69421    29.90581
#
#     HigherBound Age_group  CI_width obesity_level
# 2      19.24573     Adult   3.45195           Low
# 9      33.81534     Adult  10.72575      Moderate
# 15     31.21326     Adult   6.28849      Moderate
# 17     35.57493     Adult   7.41425          High
# 18     37.47086     Adult   7.56505          High

# %%
df_malnutrition['malnutrition_level']='nan'

# %%
###adding obesity level with conditions in df_malnut
import numpy as np

conditions = [
   df_malnutrition['mean_estimate'] >= 20,
    (df_malnutrition['mean_estimate'] >= 10) & (df_malnutrition['mean_estimate'] < 20),
    df_malnutrition['mean_estimate'] < 10
]

choices = ['High', 'Moderate', 'Low']

df_malnutrition['malnutrition_level'] = np.select(conditions, choices)
df_malnutrition.head()
# Out:
#   Country                 Region  year  gender  mean_estimate  LowerBound  \
# 0     ARE  Eastern Mediterranean  2013    Male        3.00419     1.94130
# 2     GAB                 Africa  2021  Female        5.79511     3.97204
# 6     MNG        Western Pacific  2017    Both        3.09065     2.42823
# 7     SLE                 Africa  2016  Female        8.37172     6.65567
# 9    SEAR                   None  2021    Both       13.33635    12.24232
#
#    HigherBound Age_group  CI_width malnutrition_level
# 0      4.32408     Adult   2.38278                Low
# 2      8.07702     Adult   4.10498                Low
# 6      3.84215     Adult   1.41392                Low
# 7     10.25312     Adult   3.59745                Low
# 9     14.44287     Adult   2.20055           Moderate

# %%
df_obesity.shape
# Out:
# (27720, 10)

# %%
df_obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27720 entries, 0 to 62364
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        27720 non-null  object
#  1   Region         26268 non-null  object
#  2   year           27720 non-null  int64
#  3   gender         27720 non-null  object
#  4   mean_estimate  27720 non-null  float64
#  5   LowerBound     27720 non-null  float64
#  6   HigherBound    27720 non-null  float64
#  7   Age_group      27720 non-null  object
#  8   CI_width       27720 non-null  float64
#  9   obesity_level  27720 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 2.3+ MB

# %%
df_obesity.isnull().sum()
# Out:
# Country             0
# Region           1452
# year                0
# gender              0
# mean_estimate       0
# LowerBound          0
# HigherBound         0
# Age_group           0
# CI_width            0
# obesity_level       0
# dtype: int64

# %%
import pycountry

# %%
special_cases = {
    'GLOBAL': 'Global',
    'WB_LMI': 'Low & Middle Income',
    'WB_HI': 'High Income',
    'WB_LI': 'Low Income',
    'EMR': 'Eastern Mediterranean Region',
    'EUR': 'Europe',
    'AFR': 'Africa',
    'SEAR': 'South-East Asia Region',
    'WPR': 'Western Pacific Region',
    'AMR': 'Americas Region',
    'WB_UMI': 'Upper Middle Income'
}
def convert_country_code(code):
    if code in special_cases:
        return special_cases[code]
    try:
        country = pycountry.countries.get(alpha_3= code)
        return country.name if country else code
    except:
        return code

df_obesity['Country']= df_obesity['Country'].apply(convert_country_code)
df_obesity.head()
# Out:
#                       Country                 Region  year  gender  \
# 2   Iran, Islamic Republic of  Eastern Mediterranean  2020    Male
# 9                        Iraq  Eastern Mediterranean  2020    Male
# 15                  Greenland                 Europe  2014  Female
# 17                    Armenia                 Europe  2019  Female
# 18                      Malta                 Europe  2018    Both
#
#     mean_estimate  LowerBound  HigherBound Age_group  CI_width obesity_level
# 2        17.48764    15.79378     19.24573     Adult   3.45195           Low
# 9        28.33553    23.08959     33.81534     Adult  10.72575      Moderate
# 15       27.94870    24.92477     31.21326     Adult   6.28849      Moderate
# 17       31.89322    28.16068     35.57493     Adult   7.41425          High
# 18       33.69421    29.90581     37.47086     Adult   7.56505          High

# %%
special_cases = {
    'GLOBAL': 'Global',
    'WB_LMI': 'Low & Middle Income',
    'WB_HI': 'High Income',
    'WB_LI': 'Low Income',
    'EMR': 'Eastern Mediterranean Region',
    'EUR': 'Europe',
    'AFR': 'Africa',
    'SEAR': 'South-East Asia Region',
    'WPR': 'Western Pacific Region',
    'AMR': 'Americas Region',
    'WB_UMI': 'Upper Middle Income'
}
def convert_country_code(code):
    if code in special_cases:
        return special_cases[code]
    try:
        country = pycountry.countries.get(alpha_3= code)
        return country.name if country else code
    except:
        return code

df_malnutrition['Country']= df_malnutrition['Country'].apply(convert_country_code)
df_malnutrition.head()
# Out:
#                   Country                 Region  year  gender  mean_estimate  \
# 0    United Arab Emirates  Eastern Mediterranean  2013    Male        3.00419
# 2                   Gabon                 Africa  2021  Female        5.79511
# 6                Mongolia        Western Pacific  2017    Both        3.09065
# 7            Sierra Leone                 Africa  2016  Female        8.37172
# 9  South-East Asia Region                   None  2021    Both       13.33635
#
#    LowerBound  HigherBound Age_group  CI_width malnutrition_level
# 0     1.94130      4.32408     Adult   2.38278                Low
# 2     3.97204      8.07702     Adult   4.10498                Low
# 6     2.42823      3.84215     Adult   1.41392                Low
# 7     6.65567     10.25312     Adult   3.59745                Low
# 9    12.24232     14.44287     Adult   2.20055           Moderate

# %%
df_malnutrition.head()
# Out:
#                   Country                 Region  year  gender  mean_estimate  \
# 0    United Arab Emirates  Eastern Mediterranean  2013    Male        3.00419
# 2                   Gabon                 Africa  2021  Female        5.79511
# 6                Mongolia        Western Pacific  2017    Both        3.09065
# 7            Sierra Leone                 Africa  2016  Female        8.37172
# 9  South-East Asia Region                   None  2021    Both       13.33635
#
#    LowerBound  HigherBound Age_group  CI_width malnutrition_level
# 0     1.94130      4.32408     Adult   2.38278                Low
# 2     3.97204      8.07702     Adult   4.10498                Low
# 6     2.42823      3.84215     Adult   1.41392                Low
# 7     6.65567     10.25312     Adult   3.59745                Low
# 9    12.24232     14.44287     Adult   2.20055           Moderate

# %%
df_obesity.describe()
# Out:
#                year  mean_estimate    LowerBound   HigherBound      CI_width
# count  27720.000000   27720.000000  27720.000000  27720.000000  27720.000000
# mean    2017.000000      12.761041      9.393155     17.068489      7.675334
# std        3.162335      10.858925      9.893854     12.395013      6.616899
# min     2012.000000       0.265670      0.077540      0.547850      0.216700
# 25%     2014.000000       4.753960      2.354430      7.875503      2.926715
# 50%     2017.000000       9.944540      6.506535     13.704380      5.480535
# 75%     2020.000000      17.482418     12.697755     23.986050     10.338880
# max     2022.000000      80.609250     74.365370     87.868510     40.554060

# %%
import matplotlib.pyplot as plt

# %%
df_obesity.hist()
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'mean_estimate'}>],
#        [<Axes: title={'center': 'LowerBound'}>,
#         <Axes: title={'center': 'HigherBound'}>],
#        [<Axes: title={'center': 'CI_width'}>, <Axes: >]], dtype=object)

# %%
df_malnutrition.hist()
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'TimeDim'}>],
#        [<Axes: title={'center': 'NumericValue'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'High'}>, <Axes: >]], dtype=object)

# %%
df_obesity[['mean_estimate', 'CI_width']].describe()
# Out:
#        mean_estimate      CI_width
# count   27720.000000  27720.000000
# mean       12.761041      7.675334
# std        10.858925      6.616899
# min         0.265670      0.216700
# 25%         4.753960      2.926715
# 50%         9.944540      5.480535
# 75%        17.482418     10.338880
# max        80.609250     40.554060

# %%
#df_obesity
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Mean_Estimate
plt.figure(figsize=(10, 4))
sns.histplot(df_obesity['mean_estimate'], kde=True, bins=30)
plt.title('Distribution of Mean_Estimate of obesity')
plt.xlabel('mean_estimate')
plt.ylabel('Frequency')
plt.show()

# Plot CI_Width
plt.figure(figsize=(10, 4))
sns.histplot(df_obesity['CI_width'], kde=True, bins=30)
plt.title('Distribution of CI_Width of obesity')
plt.xlabel('CI_width')
plt.ylabel('Frequency')
plt.show()

# %%
#obesity boxplot
plt.figure(figsize=(8, 4))
sns.boxplot(x=df_obesity['mean_estimate'])
plt.title('Boxplot of Mean_Estimate')
plt.show()

plt.figure(figsize=(8, 4))
sns.boxplot(x=df_obesity['CI_width'])
plt.title('Boxplot of CI_Width')
plt.show()

# %%
df_malnutrition[['mean_estimate', 'CI_width']].describe()
# Out:
#        mean_estimate      CI_width
# count   27720.000000  27720.000000
# mean        5.354451      4.750795
# std         4.811220      4.257684
# min         0.175310      0.166680
# 25%         2.039283      1.603222
# 50%         3.597790      3.351095
# 75%         7.335245      6.530875
# max        35.894110     26.701740

# %%
#df_malnutition distribution of mean_estimate and ci_width
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Mean_Estimate
plt.figure(figsize=(10, 4))
sns.histplot(df_malnutrition['mean_estimate'], kde=True, bins=30)
plt.title('Distribution of Mean_Estimate of malnutrition')
plt.xlabel('mean_estimate')
plt.ylabel('Frequency')
plt.show()

# Plot CI_Width
plt.figure(figsize=(10, 4))
sns.histplot(df_malnutrition['CI_width'], kde=True, bins=30)
plt.title('Distribution of CI_Width of malnutrition')
plt.xlabel('CI_width')
plt.ylabel('Frequency')
plt.show()

# %%
#malnutrition boxplot
plt.figure(figsize=(8, 4))
sns.boxplot(x=df_malnutrition['mean_estimate'])
plt.title('Boxplot of Mean_Estimate')
plt.show()

plt.figure(figsize=(8, 4))
sns.boxplot(x=df_malnutrition['CI_width'])
plt.title('Boxplot of CI_Width')
plt.show()

# %%
# trends across years in obesity

import seaborn as sns
import matplotlib.pyplot as plt

# Average per year
df_yearly= df_obesity.groupby('year', as_index=False)[['mean_estimate', 'CI_width']].mean()

sns.lineplot(data=df_yearly, x='year', y='mean_estimate', marker='o')
plt.title('Mean_Estimate Over Years')
plt.show()

sns.lineplot(data=df_yearly, x='year', y='CI_width', marker='o')
plt.title('CI_Width Over Years')
plt.show()

# %%
# trends across years in mal_nutrition

import seaborn as sns
import matplotlib.pyplot as plt

# Average per year
df_yearly= df_malnutrition.groupby('year', as_index=False)[['mean_estimate', 'CI_width']].mean()

sns.lineplot(data=df_yearly, x='year', y='mean_estimate', marker='o')
plt.title('Mean_Estimate Over Years')
plt.show()

sns.lineplot(data=df_yearly, x='year', y='CI_width', marker='o')
plt.title('CI_Width Over Years')
plt.show()

# %%
# trends by region for obesity mean_estimate

sns.lineplot(data=df_obesity, x='year', y='mean_estimate', hue='Region', estimator='mean', marker='o')
plt.title('Mean_Estimate by Region Over Years')
plt.show()

# %%
# trends by region for malnutrition mean_estimate

sns.lineplot(data=df_malnutrition, x='year', y='mean_estimate', hue='Region', estimator='mean', marker='o')
plt.title('Mean_Estimate by Region Over Years')
plt.show()

# %%
# trends by region of obesity ci_width

sns.lineplot(data=df_obesity,x='year',y='CI_width',hue='Region',estimator='mean',marker='o')
plt.title('CI_Width by Region over years')
plt.show()

# %%
# trends by region of malnutrition ci_width

sns.lineplot(data=df_malnutrition,x='year',y='CI_width',hue='Region',estimator='mean',marker='o')
plt.title('CI_Width by Region over years')
plt.show()

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
myconnection = pymysql.connect(host = '127.0.0.1',user='root',passwd='elakya@1993')
cur=myconnection.cursor()

# %%
myconnection = pymysql.connect(host = '127.0.0.1',user='root',passwd='elakya@1993',database='nurtition_paradox')

# %%
cur=myconnection.cursor()

# %%
####created table in sql for obesity
cur.execute("create table obesity(Country varchar(20),Region varchar(20),year int,gender varchar(10),mean_estimate int,LowerBound int,HigherBound int,Age_group varchar(10),CI_width int,obesity_level varchar(10))")
# Out:
# 0

# %%
cur.execute("ALTER TABLE obesity MODIFY Country VARCHAR(200)")
# Out:
# 0

# %%
cur.execute("ALTER TABLE obesity MODIFY Region VARCHAR(200)")
# Out:
# 0

# %%
####created table in sql for mal_nutrition
cur.execute("create table malnutrtion(Country varchar(20),Region varchar(20),year int,gender varchar(10),mean_estimate int,LowerBound int,HigherBound int,Age_group varchar(10),CI_width int,malnutrition_level varchar(10))")
# Out:
# 0

# %%
cur.execute("ALTER TABLE malnutrtion MODIFY Country VARCHAR(100);")
# Out:
# 0

# %%
cur.execute("ALTER TABLE malnutrtion MODIFY Region VARCHAR(100);")
# Out:
# 0

# %%
# fetching data in obesity table

for index, row in df_obesity.iterrows():
    cur.execute("""
        INSERT INTO obesity(Country, Region, year, gender, mean_estimate, LowerBound, HigherBound, Age_group, CI_width, obesity_level)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """, (
        row['Country'], row['Region'], row['year'], row['gender'],
        row['mean_estimate'], row['LowerBound'], row['HigherBound'],
        row['Age_group'], row['CI_width'], row['obesity_level']
    ))

# %%
myconnection.commit()

# %%
# fetching data in malnutrition table

for index, row in df_malnutrition.iterrows():
    cur.execute("""
        INSERT INTO malnutrtion(Country, Region, year, gender, mean_estimate, LowerBound, HigherBound, Age_group, CI_width, malnutrition_level)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """, (
        row['Country'], row['Region'], row['year'], row['gender'],
        row['mean_estimate'], row['LowerBound'], row['HigherBound'],
        row['Age_group'], row['CI_width'], row['malnutrition_level']
    ))

# %%
myconnection.commit()

# %%
cur.execute("select * from obesity")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                          Country                 Region  year  gender  \
# 0      Iran, Islamic Republic of  Eastern Mediterranean  2020    Male
# 1                           Iraq  Eastern Mediterranean  2020    Male
# 2                      Greenland                 Europe  2014  Female
# 3                        Armenia                 Europe  2019  Female
# 4                          Malta                 Europe  2018    Both
# ...                          ...                    ...   ...     ...
# 27715                 Tajikistan                 Europe  2020    Both
# 27716                    Somalia  Eastern Mediterranean  2012  Female
# 27717                    Vanuatu        Western Pacific  2021    Male
# 27718                 Madagascar                 Africa  2014    Male
# 27719                    Finland                 Europe  2017    Male
#
#        mean_estimate  LowerBound  HigherBound Age_group  CI_width  \
# ...

# %%
cur.execute("select * from malnutrtion")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                       Country                 Region  year  gender  \
# 0        United Arab Emirates  Eastern Mediterranean  2013    Male
# 1                       Gabon                 Africa  2021  Female
# 2                    Mongolia        Western Pacific  2017    Both
# 3                Sierra Leone                 Africa  2016  Female
# 4      South-East Asia Region                   None  2021    Both
# ...                       ...                    ...   ...     ...
# 27715                   Haiti               Americas  2013  Female
# 27716              Tajikistan                 Europe  2018    Both
# 27717        Papua New Guinea        Western Pacific  2016    Both
# 27718                   Samoa        Western Pacific  2020  Female
# 27719                 Iceland                 Europe  2018    Male
#
#        mean_estimate  LowerBound  HigherBound Age_group  CI_width  \
# 0                  3           2            4     Adult         2
# ...

# %%
# query##1 in obesity
# Top 5 regions with the highest average obesity levels in the most recent year(2022)

cur.execute("select Region, avg(mean_estimate) as average_obesity from obesity where year=2022 group by Region order by average_obesity desc limit 5;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                   Region average_obesity
# 0        Western Pacific         22.9944
# 1               Americas         21.2230
# 2  Eastern Mediterranean         18.1098
# 3                 Europe         12.9760
# 4                   None         11.4318

# %%
# query##2 in obesity
# Top 5 countries with highest obesity estimates

cur.execute("select Country,mean_estimate from obesity  order by mean_estimate desc limit 5;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#           Country  mean_estimate
# 0  American Samoa             81
# 1  American Samoa             80
# 2  American Samoa             80
# 3  American Samoa             80
# 4  American Samoa             79

# %%
# query##3 in obesity
# Obesity trend in India over the years(Mean_estimate)

cur.execute("select year,mean_estimate from obesity where Country='India' order by year asc ;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#      year  mean_estimate
# 0    2012              3
# 1    2012              5
# 2    2012              4
# 3    2012              3
# 4    2012              1
# ..    ...            ...
# 127  2022              5
# 128  2022              3
# 129  2022              2
# 130  2022              5
# 131  2022              4
#
# [132 rows x 2 columns]

# %%
# query##4 in obesity
# Average obesity by gender
cur.execute("select gender,avg(mean_estimate) as average_obesity from obesity group by gender;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#    gender average_obesity
# 0    Male         12.7719
# 1  Female         12.7229
# 2    Both         12.7787

# %%
# query##5 in obesity
# Country count by obesity level category and age group

cur.execute("SELECT obesity_level, Age_group, COUNT(DISTINCT Country) AS country_count FROM obesity GROUP BY obesity_level, Age_group ORDER BY obesity_level, Age_group;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#   obesity_level Age_group  country_count
# 0          High     Adult             94
# 1          High     Child             11
# 2           Low     Adult            176
# 3           Low     Child            210
# 4      Moderate     Adult             99
# 5      Moderate     Child             26

# %%
# query##6 in obesity
# Top 5 countries least reliable countries(with highest CI_Width)

cur.execute("SELECT Country,avg(CI_width)  as avg_ci_width from obesity group by Country order by country desc limit 5;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                   Country avg_ci_width
# 0                Zimbabwe       3.8864
# 1                  Zambia       5.9394
# 2                   Yemen       8.6212
# 3  Western Pacific Region       1.8106
# 4                Viet Nam       2.4167

# %%
# query##6 in obesity
# Top 5 most consistent countries (smallest average CI_Width)


cur.execute("SELECT Country,avg(CI_width)  as avg_ci_width from obesity group by Country order by country asc limit 5;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#           Country avg_ci_width
# 0     Afghanistan       7.7652
# 1          Africa       1.4545
# 2         Albania       4.4621
# 3         Algeria      13.8106
# 4  American Samoa      23.0909

# %%
# query##7 in obesity

# Average obesity by age group

cur.execute("select Age_group,avg(mean_estimate) as average_obesity from obesity group by Age_group order by Age_group;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#   Age_group average_obesity
# 0     Adult         21.8255
# 1     Child          9.7353

# %%
# query##8 in obesity
# Top 10 Countries with consistent low obesity (low average + low CI)over the years

cur.execute("SELECT Country,AVG(mean_estimate) AS avg_obesity, AVG(CI_width) AS avg_ci_width FROM obesity GROUP BY Country ORDER BY avg_obesity ASC, avg_ci_width ASC LIMIT 10;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#         Country avg_obesity avg_ci_width
# 0   Timor-Leste      1.1364       1.3030
# 1      Ethiopia      1.5152       1.5682
# 2        Rwanda      1.7500       2.3864
# 3  Burkina Faso      1.8333       1.5227
# 4    Bangladesh      1.9318       1.6742
# 5    Madagascar      1.9394       4.3636
# 6       Burundi      2.2879       5.1970
# 7        Malawi      2.3864       2.6288
# 8         Nepal      2.4848       3.0909
# 9    Mozambique      2.7652       2.7273

# %%
# QUERY##9
# Countries where female obesity exceeds male by large margin (same       year)
cur.execute("SELECT f.Country,f.year,f.mean_estimate AS female_obesity, m.mean_estimate AS male_obesity, (f.mean_estimate - m.mean_estimate) AS difference FROM obesity f JOIN obesity m ON f.Country = m.Country AND f.year = m.year AND f.Age_group = m.Age_group WHERE f.gender = 'Female' AND m.gender = 'Male' AND (f.mean_estimate - m.mean_estimate) > 5 ORDER BY difference DESC;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                   Country  year  female_obesity  male_obesity  difference
# 0            South Africa  2022              46            13          33
# 1            South Africa  2021              45            13          32
# 2            South Africa  2020              44            13          31
# 3            South Africa  2019              44            13          31
# 4                 Jamaica  2021              48            18          30
# ...                   ...   ...             ...           ...         ...
# 1539                 Iraq  2018              19            13           6
# 1540                 Iraq  2017              18            12           6
# 1541              Bahamas  2021              34            28           6
# 1542  Antigua and Barbuda  2018              25            19           6
# 1543          Puerto Rico  2021              23            17           6
#
# [1544 rows x 5 columns]

# %%
# QUERY##10
# Global average obesity percentage per year
cur.execute("select year, avg(mean_estimate) as avg_obesity from obesity group by year order by year asc;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#     year avg_obesity
# 0   2012     11.0575
# 1   2013     11.3627
# 2   2014     11.6587
# 3   2015     11.9933
# 4   2016     12.3218
# 5   2017     12.6925
# 6   2018     13.0595
# 7   2019     13.4468
# 8   2020     13.8401
# 9   2021     14.2476
# 10  2022     14.6556

# %%
# malnutrition query 1
# Avg. malnutrition by age group
cur.execute("select Age_group, avg(mean_estimate) as avg_malnutrition from malnutrtion group by Age_group order by Age_group asc;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#   Age_group avg_malnutrition
# 0     Adult           5.9522
# 1     Child           5.1623

# %%
# malnutrition query 2
# Top 5 countries with highest malnutrition(mean_estimate)
cur.execute("select Country,mean_estimate from malnutrtion order by mean_estimate desc limit 5;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#    Country  mean_estimate
# 0  Eritrea             36
# 1  Eritrea             36
# 2  Eritrea             35
# 3  Eritrea             35
# 4  Eritrea             35

# %%
# malnutrition query 3
#Malnutrition trend in African region over the years
cur.execute("select year,avg(mean_estimate) as avg_malnutrition from malnutrtion where Region='Africa' group by year order by year asc;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#     year avg_malnutrition
# 0   2012           8.8457
# 1   2013           8.7500
# 2   2014           8.6436
# 3   2015           8.5851
# 4   2016           8.5248
# 5   2017           8.4574
# 6   2018           8.4096
# 7   2019           8.3475
# 8   2020           8.3050
# 9   2021           8.2748
# 10  2022           8.2553

# %%
# malnutrition query 4
# Gender-based average malnutrition
cur.execute("select gender, avg(mean_estimate) as avg_malnutrition from malnutrtion group by gender order by gender;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#    gender avg_malnutrition
# 0    Both           5.3603
# 1  Female           4.6832
# 2    Male           6.0359

# %%
# malnutrition query 5
# Malnutrition level-wise (average CI_Width by age group)p
cur.execute("select malnutrition_level,Age_group,avg(CI_width) as avg_CIwidth from malnutrtion group by malnutrition_level,Age_group order by malnutrition_level,Age_group;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#   malnutrition_level Age_group avg_CIwidth
# 0               High     Adult      9.2798
# 1               High     Child      7.8832
# 2                Low     Adult      2.6371
# 3                Low     Child      4.4393
# 4           Moderate     Adult      7.6348
# 5           Moderate     Child      9.8930

# %%
# malnutrition query 6
# Yearly malnutrition change in specific countries(India, Nigeria, Brazil)
cur.execute("select Country,year,avg(mean_estimate) as avg_malnutrition from malnutrtion where Country IN ('India','Nigeria','Brazil') group by country,year order by Country,year;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#     Country  year avg_malnutrition
# 0    Brazil  2012           3.0000
# 1    Brazil  2013           2.6667
# 2    Brazil  2014           2.5833
# 3    Brazil  2015           2.5833
# 4    Brazil  2016           2.5833
# 5    Brazil  2017           2.5833
# 6    Brazil  2018           2.7500
# 7    Brazil  2019           2.7500
# 8    Brazil  2020           2.7500
# 9    Brazil  2021           2.7500
# 10   Brazil  2022           2.7500
# 11    India  2012          25.1667
# 12    India  2013          24.6667
# 13    India  2014          24.0833
# 14    India  2015          23.4167
# 15    India  2016          22.7500
# 16    India  2017          22.1667
# 17    India  2018          21.5000
# 18    India  2019          21.0000
# 19    India  2020          20.1667
# 20    India  2021          19.7500
# 21    India  2022          19.0833
# 22  Nigeria  2012          11.3333
# 23  Nigeria  2013          11.2500
# 24  Nigeria  2014          11.4167
# 25  Nigeria  2015          11.5833
# ...

# %%
# malnutrition query 7
#Regions with lowest malnutrition averages
cur.execute("select Region,avg(mean_estimate) as avg_malnutrition from malnutrtion group by Region order by avg_malnutrition asc;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                   Region avg_malnutrition
# 0                 Europe           2.4433
# 1               Americas           3.1779
# 2        Western Pacific           3.2318
# 3  Eastern Mediterranean           6.6694
# 4                   None           8.3588
# 5                 Africa           8.4908
# 6        South-East Asia          13.2934

# %%
# malnutrition query 8
# malnutritionCountries with increasing malnutrition (💡 Hint: Use MIN() and MAX()   on Mean_Estimate per country to compare early vs. recent malnutrition levels, and filter where the difference is positive using HAVING.)Countries with increasing malnutrition (💡 Hint: Use MIN() and MAX()   on Mean_Estimate per country to compare early vs. recent malnutrition levels, and filter where the difference is positive using HAVING.)
cur.execute("SELECT Country,MIN(year) AS from_year,MAX(year) AS to_year,MIN(mean_estimate) AS earliest_malnutrition,MAX(mean_estimate) AS latest_malnutrition,(MAX(mean_estimate) - MIN(mean_estimate)) AS difference FROM malnutrtion GROUP BY Country HAVING MAX(mean_estimate) - MIN(mean_estimate) > 0 ORDER BY difference DESC;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#            Country  from_year  to_year  earliest_malnutrition  \
# 0          Eritrea       2012     2022                      8
# 1          Somalia       2012     2022                      5
# 2         Ethiopia       2012     2022                      8
# 3            India       2012     2022                     13
# 4      Timor-Leste       2012     2022                     10
# ..             ...        ...      ...                    ...
# 205        Bermuda       2012     2022                      4
# 206  United States       2012     2022                      1
# 207         Belize       2012     2022                      2
# 208        Bahamas       2012     2022                      3
# 209         Guyana       2012     2022                      7
#
#      latest_malnutrition  difference
# 0                     36          28
# 1                     26          21
# 2                     29          21
# 3                     32          19
# ...

# %%
# malnutrition query 9
#  Min/Max malnutrition levels year-wise comparison
cur.execute("select year, min(mean_estimate) as min_mean_est, max(mean_estimate) as max_mean_est from malnutrtion group by year order by year asc;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#     year  min_mean_est  max_mean_est
# 0   2012             0            36
# 1   2013             0            36
# 2   2014             0            35
# 3   2015             0            35
# 4   2016             0            35
# 5   2017             0            35
# 6   2018             0            35
# 7   2019             0            35
# 8   2020             0            35
# 9   2021             0            34
# 10  2022             0            34

# %%
# malnutrition query 10
# High CI_Width flags for monitoring(CI_width > 5)
cur.execute("SELECT Country, Region, year, gender, Age_group, mean_estimate, CI_width FROM malnutrtion WHERE CI_width > 5 ORDER BY CI_width DESC;;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                    Country                 Region  year gender Age_group  \
# 0                  Senegal                 Africa  2022   Male     Child
# 1                  Senegal                 Africa  2021   Male     Child
# 2                  Senegal                 Africa  2020   Male     Child
# 3               Mauritania                 Africa  2022   Male     Child
# 4               Mauritania                 Africa  2021   Male     Child
# ...                    ...                    ...   ...    ...       ...
# 8579               Senegal                 Africa  2012   Both     Child
# 8580                Rwanda                 Africa  2013   Both     Child
# 8581  United Arab Emirates  Eastern Mediterranean  2022   Male     Child
# 8582                  Togo                 Africa  2021   Both     Child
# 8583               Lebanon  Eastern Mediterranean  2021   Male     Child
#
#       mean_estimate  CI_width
# 0                17        27
# ...

# %%
# Combination queries of both tables
# query1
# Obesity vs malnutrition comparison by country(any 5 countries)
cur.execute("SELECT o.Country,o.year,avg(o.mean_estimate) as avg_ob_mean_estimate, avg(m.mean_estimate) as avg_malnut_mean_estimate FROM obesity o JOIN malnutrtion m ON o.Country=m.Country AND o.year=m.year where o.Country IN ('India','Mauritania','Nigeria','Brazil','Senegal') group by o.Country,o.year order by o.Country,o.year;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#        Country  year avg_ob_mean_estimate avg_malnut_mean_estimate
# 0       Brazil  2012              13.5833                   3.0000
# 1       Brazil  2013              14.0000                   2.6667
# 2       Brazil  2014              14.7500                   2.5833
# 3       Brazil  2015              15.3333                   2.5833
# 4       Brazil  2016              16.0000                   2.5833
# 5       Brazil  2017              16.6667                   2.5833
# 6       Brazil  2018              17.3333                   2.7500
# 7       Brazil  2019              17.8333                   2.7500
# 8       Brazil  2020              18.5000                   2.7500
# 9       Brazil  2021              19.1667                   2.7500
# 10      Brazil  2022              19.7500                   2.7500
# 11       India  2012               2.4167                  25.1667
# 12       India  2013               2.5833                  24.6667
# ...

# %%
# Combination queries of both tables
# query2
# Gender-based disparity in both obesity and malnutrition
cur.execute("SELECT o.gender,avg(o.mean_estimate) as avg_obesity, avg(m.mean_estimate) as avg_malnutrition FROM obesity o JOIN malnutrtion m ON o.Country=m.Country AND o.gender=m.gender AND o.year=m.year group by o.gender order by o.gender;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#    gender avg_obesity avg_malnutrition
# 0    Both     12.7787           5.3603
# 1  Female     12.7229           4.6832
# 2    Male     12.7719           6.0359

# %%
# Combination queries of both tables
# query3
# Region-wise avg estimates side-by-side(Africa and America)
cur.execute("SELECT o.Region,avg(o.mean_estimate) as avg_obesity, avg(m.mean_estimate) as avg_malnutrition FROM obesity o JOIN malnutrtion m ON o.Country=m.Country AND o.Region=m.Region AND o.year=m.year where o.Region IN ('Africa','Americas') group by o.Region order by o.Region;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#      Region avg_obesity avg_malnutrition
# 0    Africa      5.4123           8.4908
# 1  Americas     18.4050           3.1779

# %%
import pandas as pd

# %%
# Combination queries of both tables
# query4
# Countries with obesity up & malnutrition down
cur.execute("SELECT o.Country,MIN(o.mean_estimate) AS earliest_obesity, MAX(o.mean_estimate) AS latest_obesity, MIN(m.mean_estimate) AS earliest_malnutrition, MAX(m.mean_estimate) AS latest_malnutrition FROM obesity o JOIN malnutrtion m ON o.Country = m.Country AND o.year = m.year GROUP BY o.Country HAVING MAX(o.mean_estimate) > MIN(o.mean_estimate) AND MAX(m.mean_estimate) < MIN(m.mean_estimate) ORDER BY o.Country;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
# Empty DataFrame
# Columns: [Country, earliest_obesity, latest_obesity, earliest_malnutrition, latest_malnutrition]
# Index: []

# %%
# Combination queries of both tables
# query5
# Age-wise trend analysis
cur.execute("SELECT o.Country,o.Age_group,o.year,avg(o.mean_estimate) as avg_obesity, avg(m.mean_estimate) as avg_malnutrition FROM obesity o JOIN malnutrtion m ON o.Age_group=m.Age_group AND o.year=m.year AND o.Country=m.Country group by Age_group,year,Country order by Age_group,year,Country limit 1000;")
result = cur.fetchall()
data= pd.DataFrame(result,columns=[i[0] for i in cur.description])
data
# Out:
#                    Country Age_group  year avg_obesity avg_malnutrition
# 0              Afghanistan     Adult  2012      9.0000          11.6667
# 1                   Africa     Adult  2012      7.6667          12.6667
# 2                  Albania     Adult  2012     19.0000           1.3333
# 3                  Algeria     Adult  2012     18.0000           6.0000
# 4           American Samoa     Adult  2012     72.3333           0.0000
# ..                     ...       ...   ...         ...              ...
# 995                Romania     Adult  2016     30.0000           2.3333
# 996     Russian Federation     Adult  2016     25.6667           3.0000
# 997                 Rwanda     Adult  2016      3.0000           9.0000
# 998  Saint Kitts and Nevis     Adult  2016     42.0000           3.0000
# 999            Saint Lucia     Adult  2016     29.0000           4.3333
#
# [1000 rows x 5 columns]

# %% [markdown]
# ###**SUMMARY REPORT: Obesity & Malnutrition Global Analysis**

# %% [markdown]
# #**Data cleaning and preparation:**

# %% [markdown]
# - The two datasets used here: obesity and malnutrtion
#
#    - 1.Missing values are removed using pandas.
#
#    - 2.Derived columns are CI_width,Mean_estimate such as obesity_level calculated.
#
#    - 3.Standardized the columns in both datasets.
#
#    - 4.Duplicates were resolved.
#
#    - 5.Datas loaded into sql for further queries

# %% [markdown]
# - **SQL based analysis:**
#     - 1.Age_group trend analysis in obesity and malnutrtion
#
#     - 2.Top 10 high and low obesity/malnutrition were analysed.
#
#     - 3.Year wise trend analysis for both groups
#
#     - 4.country count by obesity level and age group
#
#     - 5.Gender-based average malnutrition
#
#     - 6.Regions with lowest malnutrition averages
#
#     - 7.Countries with obesity up & malnutrition down
#
#     - 8.Obesity vs malnutrition comparison by country

# %% [markdown]
# - **Visualization using POWERBI**
#
#     - 1.Line chart for trend analysis
#
#     - 2.Clustered Column Chart for Country-wise obesity vs malnutrition
#
#     - 3.Pie chart for Age_group and country analysis
#
#     - 4.Scatter plot for Ci_width,mean_estimate per country
#
#     - 5.stacked bar chart for obesity and malnutrition level analysis.

# %% [markdown]
# ###**Key Insights:**

# %% [markdown]
# - **OBESITY TRENDS OVER TIME**
#     - Obesity level is increasing globally year by year.
#
#     - The Western Pacific,American,Eastern Mediterranean regions are in high obesity levels.
#
#     - In countries like the USA, Brazil, Egypt, obesity is nearing or exceeding 30% on average.

# %% [markdown]
# - **MALNUTRITION TRENDS OVER TIME**
#     - Malnutrition is decreasing overall, but certain African and South Asian countries still show persistently high levels.
#
#     - Some countries (e.g., India, Nigeria) have shown steady improvement, but others like Yemen, Sudan have seen fluctuations.

# %% [markdown]
# - **Recommendations**
#
#     - *Regions Needing Urgent Intervention*
#         - Sub-Saharan Africa: High malnutrition + high CI_Width → requires both health and data investment.
#
#         - Eastern Mediterranean and Americas: High obesity → needs preventive health policies.
#
#     - Implement school nutrition programs for younger age groups.
#
#     - Female-targeted campaigns in high-obesity regions.

# %% [markdown]
# - **Conclusion**
#
#     - This comprehensive analysis combines SQL-driven insights with Power BI visual storytelling to highlight critical trends and support data-driven health interventions.
#     - By identifying at-risk regions and populations, policymakers can act early and strategically to combat both forms of malnutrition.
